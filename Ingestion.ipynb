# %%
import sqlalchemy

engine = sqlalchemy.create_engine('postgresql://admin:admin123@localhost:5432/minilab_db')

with engine.connect() as conn:
    conn.execute(sqlalchemy.text("""
    CREATE TABLE IF NOT EXISTS anggota (
        anggota_id   INT PRIMARY KEY,
        nama         VARCHAR(100),
        kota         VARCHAR(100),
        umur         INT,
        tanggal_daftar DATE
    );

    INSERT INTO anggota VALUES
    (1,  'Alfian',   'Surabaya',   22, '2024-01-05'),
    (2,  'Brenda',   'Jakarta',    25, '2024-02-10'),
    (3,  'Cahyo',    'Bandung',    28, '2024-01-15'),
    (4,  'Dinda',    'Malang',     21, '2024-03-01'),
    (5,  'Erwin',    'Semarang',   30, '2024-02-20'),
    (6,  'Fauzia',   'Yogyakarta', 24, '2024-01-28'),
    (7,  'Gilang',   'Medan',      27, '2024-03-10'),
    (8,  'Hesti',    'Makassar',   23, '2024-02-05'),
    (9,  'Ilham',    'Depok',      31, '2023-12-20'),
    (10, 'Jasmine',  'Bekasi',     26, '2024-01-18'),
    (11, 'Kevin',    'Surabaya',   29, '2024-03-22'),
    (12, 'Laras',    'Jakarta',    20, '2024-02-14'),
    (13, 'Mahesa',   'Bandung',    33, '2023-11-30'),
    (14, 'Nabila',   'Malang',     22, '2024-04-01'),
    (15, 'Oscar',    'Semarang',   28, '2024-01-10'),
    (16, 'Prita',    'Yogyakarta', 25, '2024-03-18'),
    (17, 'Qori',     'Medan',      32, '2023-12-10'),
    (18, 'Rendi',    'Makassar',   24, '2024-02-22'),
    (19, 'Siska',    'Jakarta',    27, '2023-11-15'),
    (20, 'Taufik',   'Surabaya',   35, '2024-01-25')
    ON CONFLICT (anggota_id) DO NOTHING;

    CREATE TABLE IF NOT EXISTS buku (
        buku_id      INT PRIMARY KEY,
        judul        VARCHAR(150),
        genre        VARCHAR(100),
        penulis      VARCHAR(100),
        tahun_terbit INT,
        stok         INT
    );

    INSERT INTO buku VALUES
    (1,  'Laskar Pelangi',           'Novel',         'Andrea Hirata',    2005, 10),
    (2,  'Bumi Manusia',             'Novel Sejarah', 'Pramoedya Ananta', 1980, 8),
    (3,  'Atomic Habits',            'Self-Help',     'James Clear',      2018, 15),
    (4,  'Sapiens',                  'Sejarah',       'Yuval Noah Harari',2011, 12),
    (5,  'The Alchemist',            'Novel',         'Paulo Coelho',     1988, 10),
    (6,  'Thinking Fast and Slow',   'Psikologi',     'Daniel Kahneman',  2011, 7),
    (7,  'Clean Code',               'Teknologi',     'Robert C. Martin', 2008, 9),
    (8,  'Deep Work',                'Self-Help',     'Cal Newport',      2016, 11),
    (9,  'Dune',                     'Fiksi Ilmiah',  'Frank Herbert',    1965, 6),
    (10, 'Filosofi Teras',           'Filsafat',      'Henry Manampiring',2018, 14),
    (11, 'Hujan',                    'Novel',         'Tere Liye',        2016, 10),
    (12, 'The Pragmatic Programmer', 'Teknologi',     'Andrew Hunt',      1999, 8),
    (13, 'Educated',                 'Biografi',      'Tara Westover',    2018, 9),
    (14, 'Midnight Library',         'Novel',         'Matt Haig',        2020, 12),
    (15, 'Python Crash Course',      'Teknologi',     'Eric Matthes',     2019, 10)
    ON CONFLICT (buku_id) DO NOTHING;

    CREATE TABLE IF NOT EXISTS peminjaman (
        pinjam_id   INT PRIMARY KEY,
        anggota_id  INT REFERENCES anggota(anggota_id),
        buku_id     INT REFERENCES buku(buku_id),
        tgl_pinjam  DATE,
        tgl_kembali DATE
    );

    INSERT INTO peminjaman VALUES
    (1,  1,  1,  '2024-01-10', '2024-01-24'),
    (2,  1,  3,  '2024-01-10', '2024-01-24'),
    (3,  2,  5,  '2024-02-12', '2024-02-26'),
    (4,  2,  14, '2024-02-12', '2024-02-26'),
    (5,  3,  7,  '2024-01-18', '2024-02-01'),
    (6,  3,  12, '2024-01-18', '2024-02-01'),
    (7,  4,  1,  '2024-03-05', '2024-03-19'),
    (8,  4,  11, '2024-03-05', '2024-03-19'),
    (9,  5,  3,  '2024-02-22', '2024-03-07'),
    (10, 5,  8,  '2024-02-22', '2024-03-07'),
    (11, 6,  4,  '2024-01-30', '2024-02-13'),
    (12, 6,  6,  '2024-01-30', '2024-02-13'),
    (13, 7,  9,  '2024-03-12', '2024-03-26'),
    (14, 7,  4,  '2024-03-12', '2024-03-26'),
    (15, 8,  10, '2024-02-07', '2024-02-21'),
    (16, 8,  6,  '2024-02-07', '2024-02-21'),
    (17, 9,  2,  '2023-12-22', '2024-01-05'),
    (18, 9,  13, '2023-12-22', '2024-01-05'),
    (19, 10, 5,  '2024-01-20', '2024-02-03'),
    (20, 10, 14, '2024-01-20', '2024-02-03'),
    (21, 11, 3,  '2024-03-24', '2024-04-07'),
    (22, 11, 8,  '2024-03-24', '2024-04-07'),
    (23, 12, 1,  '2024-02-16', '2024-03-01'),
    (24, 12, 11, '2024-02-16', '2024-03-01'),
    (25, 13, 7,  '2023-12-02', '2023-12-16'),
    (26, 13, 15, '2023-12-02', '2023-12-16'),
    (27, 14, 4,  '2024-04-03', '2024-04-17'),
    (28, 14, 6,  '2024-04-03', '2024-04-17'),
    (29, 15, 9,  '2024-01-12', '2024-01-26'),
    (30, 15, 3,  '2024-01-12', '2024-01-26'),
    (31, 16, 10, '2024-03-20', '2024-04-03'),
    (32, 16, 1,  '2024-03-20', '2024-04-03'),
    (33, 17, 2,  '2023-12-12', '2023-12-26'),
    (34, 17, 13, '2023-12-12', '2023-12-26'),
    (35, 18, 5,  '2024-02-24', '2024-03-09'),
    (36, 18, 14, '2024-02-24', '2024-03-09'),
    (37, 19, 11, '2023-11-17', '2023-12-01'),
    (38, 19, 1,  '2023-11-17', '2023-12-01'),
    (39, 20, 3,  '2024-01-27', '2024-02-10'),
    (40, 20, 8,  '2024-01-27', '2024-02-10')
    ON CONFLICT (pinjam_id) DO NOTHING;
    """))
    conn.commit()

print("✅ Tabel anggota, buku, dan peminjaman berhasil dibuat!")
# Out:
# ✅ Tabel anggota, buku, dan peminjaman berhasil dibuat!

# %%
import pandas as pd

# Dataset buku dalam format CSV
df_csv = pd.DataFrame({
    'buku_id': range(1, 16),
    'judul': [
        'Laskar Pelangi', 'Bumi Manusia', 'Atomic Habits', 'Sapiens', 'The Alchemist',
        'Thinking Fast and Slow', 'Clean Code', 'Deep Work', 'Dune', 'Filosofi Teras',
        'Hujan', 'The Pragmatic Programmer', 'Educated', 'Midnight Library', 'Python Crash Course'
    ],
    'genre': [
        'Novel', 'Novel Sejarah', 'Self-Help', 'Sejarah', 'Novel',
        'Psikologi', 'Teknologi', 'Self-Help', 'Fiksi Ilmiah', 'Filsafat',
        'Novel', 'Teknologi', 'Biografi', 'Novel', 'Teknologi'
    ],
    'penulis': [
        'Andrea Hirata', 'Pramoedya Ananta', 'James Clear', 'Yuval Noah Harari', 'Paulo Coelho',
        'Daniel Kahneman', 'Robert C. Martin', 'Cal Newport', 'Frank Herbert', 'Henry Manampiring',
        'Tere Liye', 'Andrew Hunt', 'Tara Westover', 'Matt Haig', 'Eric Matthes'
    ],
    'rating': [4.8, 4.9, 4.7, 4.6, 4.5, 4.4, 4.8, 4.6, 4.7, 4.5,
               4.3, 4.7, 4.6, 4.4, 4.8],
    'tersedia': ['Ya'] * 15
})

# Simpan ke file CSV
df_csv.to_csv('data_buku.csv', index=False)
print("✅ File data_buku.csv berhasil dibuat!")
print(df_csv.head())
# Out:
# ✅ File data_buku.csv berhasil dibuat!
#    buku_id           judul          genre            penulis  rating tersedia
# 0        1  Laskar Pelangi          Novel      Andrea Hirata     4.8       Ya
# 1        2    Bumi Manusia  Novel Sejarah   Pramoedya Ananta     4.9       Ya
# 2        3   Atomic Habits      Self-Help        James Clear     4.7       Ya
# 3        4         Sapiens        Sejarah  Yuval Noah Harari     4.6       Ya
# 4        5   The Alchemist          Novel       Paulo Coelho     4.5       Ya

# %%
import pandas as pd

# Dataset anggota dalam format XLSX
df_xlsx = pd.DataFrame({
    'anggota_id': range(1, 16),
    'nama': [
        'Alfian', 'Brenda', 'Cahyo', 'Dinda', 'Erwin',
        'Fauzia', 'Gilang', 'Hesti', 'Ilham', 'Jasmine',
        'Kevin', 'Laras', 'Mahesa', 'Nabila', 'Oscar'
    ],
    'kota': [
        'Surabaya', 'Jakarta', 'Bandung', 'Malang', 'Semarang',
        'Yogyakarta', 'Medan', 'Makassar', 'Depok', 'Bekasi',
        'Surabaya', 'Jakarta', 'Bandung', 'Malang', 'Semarang'
    ],
    'umur': [22, 25, 28, 21, 30, 24, 27, 23, 31, 26, 29, 20, 33, 22, 28],
    'status_anggota': ['Aktif'] * 15,
    'tanggal_daftar': pd.date_range('2024-01-01', periods=15, freq='10D')
})

# Simpan ke file XLSX
df_xlsx.to_excel('data_anggota.xlsx', index=False)
print("✅ File data_anggota.xlsx berhasil dibuat!")
print(df_xlsx.head())
# Out:
# ✅ File data_anggota.xlsx berhasil dibuat!
#    anggota_id    nama      kota  umur status_anggota tanggal_daftar
# 0           1  Alfian  Surabaya    22          Aktif     2024-01-01
# 1           2  Brenda   Jakarta    25          Aktif     2024-01-11
# 2           3   Cahyo   Bandung    28          Aktif     2024-01-21
# 3           4   Dinda    Malang    21          Aktif     2024-01-31
# 4           5   Erwin  Semarang    30          Aktif     2024-02-10

# %%
from minio import Minio
from minio.error import S3Error
import pandas as pd
import sqlalchemy
import io

# Koneksi MinIO
client = Minio(
    "localhost:9000",
    access_key="minioadmin",
    secret_key="minioadmin123",
    secure=False
)

# Fungsi upload DataFrame ke MinIO
def upload_to_minio(df, path):
    csv_bytes = df.to_csv(index=False).encode('utf-8')
    client.put_object(
        bucket,
        path,
        data=io.BytesIO(csv_bytes),
        length=len(csv_bytes),
        content_type="text/csv"
    )
    print(f"✅ Berhasil upload: {path} ({len(df)} baris)")

# Koneksi PostgreSQL
engine = sqlalchemy.create_engine('postgresql://admin:admin123@localhost:5432/minilab_db')

# Ingestion dari RDBMS
df_pinjam  = pd.read_sql("SELECT * FROM peminjaman", engine)

upload_to_minio(df_pinjam,  "raw/rdbms/peminjaman.csv")

# Ingestion dari CSV
df_csv = pd.read_csv("data_buku.csv")
upload_to_minio(df_csv, "raw/csv/data_buku.csv")

# Ingestion dari XLSX
df_xlsx = pd.read_excel("data_anggota.xlsx")
upload_to_minio(df_xlsx, "raw/xlsx/data_anggota.csv")

print("\n🎉 Semua data berhasil diingestion ke MinIO!")
# Out:
# ✅ Bucket 'minilab-datalake' sudah ada!
# ✅ Berhasil upload: raw/rdbms/peminjaman.csv (40 baris)
# ✅ Berhasil upload: raw/csv/data_buku.csv (15 baris)
# ✅ Berhasil upload: raw/xlsx/data_anggota.csv (15 baris)
#
# 🎉 Semua data berhasil diingestion ke MinIO!

# %%
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Simpan ke file CSV
# ----> 2 df_csv.to_csv('peminjaman.csv', index=False)
#       3 print("✅ File peminjaman.csv berhasil dibuat!")
#       4 print(df_csv.head())
#
# NameError: name 'df_csv' is not defined
